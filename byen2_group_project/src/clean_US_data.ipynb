# %%
import numpy as np
import pandas as pd


df = pd.read_csv("../data/USvideos.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
# ...

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
df.drop(df.columns[[0,1,5,7,8,9,10,11,12,13,14]], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          40949 non-null  object
#  1   channel_title  40949 non-null  object
#  2   category_id    40949 non-null  int64
#  3   tags           40949 non-null  object
#  4   description    40379 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.6+ MB

# %%
#remove rows with no values
rows_with_nan = [index for index, row in df.iterrows() if row.isnull().any()]

# %%
print("Rows with NaN: ", len(rows_with_nan))
df.drop(rows_with_nan, inplace = True)
# Out:
# Rows with NaN:  570

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40379 entries, 0 to 40948
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          40379 non-null  object
#  1   channel_title  40379 non-null  object
#  2   category_id    40379 non-null  int64
#  3   tags           40379 non-null  object
#  4   description    40379 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.8+ MB

# %%
#remove stopwords from df
from nltk.corpus import stopwords

stop = stopwords.words("english")

# %%
#clean puntuation
def clean_punct(x):
    try:
        x = x.str.replace('"','')
        x = x.str.replace('[^\w\s]',' ')
    except:
        pass
    return x

df_no_punctuation = df.apply(clean_punct)
# Out:
# <ipython-input-10-207da87db145>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   x = x.str.replace('[^\w\s]',' ')

# %%
df_no_punctuation.head()
# Out:
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency  Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman   Rudy Mancuso  King Bach   Le...           Rudy Mancuso
# 3                   Nickelback Lyrics  Real or Fake   Good Mythical Morning
# 4                           I Dare You  GOING BALD                 nigahiga
#
#    category_id                                               tags  \
# 0           22                                    SHANtell martin
# 1           24  last week tonight trump presidency last week t...
# 2           23  racist superman rudy mancuso king bach racist ...
# 3           24  rhett and link gmm good mythical morning rhett...
# 4           24  ryan higa higatv nigahiga i dare you idy rhpc ...
#
#                                          description
# 0  SHANTELL S CHANNEL   https   www youtube com s...
# ...

# %%
#prep for removing stopwords by lowercase/split
df_lower = df_no_punctuation.apply(lambda x: x.astype(str).str.lower().str.split())

# %%
df_lower.head()
# Out:
#                                                title  \
# 0         [we, want, to, talk, about, our, marriage]
# 1  [the, trump, presidency, last, week, tonight, ...
# 2  [racist, superman, rudy, mancuso, king, bach, ...
# 3               [nickelback, lyrics, real, or, fake]
# 4                        [i, dare, you, going, bald]
#
#                channel_title category_id  \
# 0             [caseyneistat]        [22]
# 1          [lastweektonight]        [24]
# 2            [rudy, mancuso]        [23]
# 3  [good, mythical, morning]        [24]
# 4                 [nigahiga]        [24]
#
#                                                 tags  \
# 0                                 [shantell, martin]
# 1  [last, week, tonight, trump, presidency, last,...
# 2  [racist, superman, rudy, mancuso, king, bach, ...
# 3  [rhett, and, link, gmm, good, mythical, mornin...
# 4  [ryan, higa, higatv, nigahiga, i, dare, you, i...
#
#                                          description
# ...

# %%
#remove all stopwords
df_lower['title'] = df_lower['title'].apply(lambda x: [item for item in x if item not in stop])
df_lower['channel_title'] = df_lower['channel_title'].apply(lambda x: [item for item in x if item not in stop])
df_lower['tags'] = df_lower['tags'].apply(lambda x: [item for item in x if item not in stop])
df_lower['description'] = df_lower['description'].apply(lambda x: [item for item in x if item not in stop])

# %%
df_lower.head()
# Out:
#                                                title  \
# 0                             [want, talk, marriage]
# 1  [trump, presidency, last, week, tonight, john,...
# 2  [racist, superman, rudy, mancuso, king, bach, ...
# 3                   [nickelback, lyrics, real, fake]
# 4                                [dare, going, bald]
#
#                channel_title category_id  \
# 0             [caseyneistat]        [22]
# 1          [lastweektonight]        [24]
# 2            [rudy, mancuso]        [23]
# 3  [good, mythical, morning]        [24]
# 4                 [nigahiga]        [24]
#
#                                                 tags  \
# 0                                 [shantell, martin]
# 1  [last, week, tonight, trump, presidency, last,...
# 2  [racist, superman, rudy, mancuso, king, bach, ...
# 3  [rhett, link, gmm, good, mythical, morning, rh...
# 4  [ryan, higa, higatv, nigahiga, dare, idy, rhpc...
#
#                                          description
# ...

# %%
df_final = df_lower.apply(lambda x: x.astype(str).str.replace(',',';'))
df_final = df_final.apply(lambda x: x.astype(str).str.replace('\'',''))
df_final = df_final.apply(lambda x: x.astype(str).str.replace('[',''))
df_final = df_final.apply(lambda x: x.astype(str).str.replace(']',''))
# Out:
# <ipython-input-16-85d7407676f7>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_final = df_final.apply(lambda x: x.astype(str).str.replace('[',''))
# <ipython-input-16-85d7407676f7>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_final = df_final.apply(lambda x: x.astype(str).str.replace(']',''))

# %%
df_final.head()
# Out:
#                                                title            channel_title  \
# 0                               want; talk; marriage             caseyneistat
# 1  trump; presidency; last; week; tonight; john; ...          lastweektonight
# 2  racist; superman; rudy; mancuso; king; bach; l...            rudy; mancuso
# 3                     nickelback; lyrics; real; fake  good; mythical; morning
# 4                                  dare; going; bald                 nigahiga
#
#   category_id                                               tags  \
# 0          22                                   shantell; martin
# 1          24  last; week; tonight; trump; presidency; last; ...
# 2          23  racist; superman; rudy; mancuso; king; bach; r...
# 3          24  rhett; link; gmm; good; mythical; morning; rhe...
# 4          24  ryan; higa; higatv; nigahiga; dare; idy; rhpc;...
#
#                                          description
# ...

# %%
df_final.to_csv("US_video_cleaned.csv")
